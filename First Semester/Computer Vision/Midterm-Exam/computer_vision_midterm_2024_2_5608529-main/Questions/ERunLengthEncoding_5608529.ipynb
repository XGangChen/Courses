# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import math
from IPython.display import display, HTML

# %%
student_id = input("Enter your student id")
student_name = input("Enter your name")
print("STUDENT ID", student_id)
print("STUDENT NAME", student_name)

# %% [markdown]
# <!-- <div class="question_frame"> --><!-- start of question_frame -->

# %% [markdown]
# <h1>Run Length Encoding</h1><div class="question_body"><p>You are given a string consisting of [0, 1, 2, 3, 4] from 0 to 9.</p><p>A sample string is 000000333333334444444</p><p>The <emph>run length encoding</emph> of a string replaces all runs ofdigits <code>d</code> are replaced with a pairs of single digit counts<code>count</code> (from 1 to 9) and a <code>d</code>.</p><p>The count is limited to a single digit, so the maximum run of acharacter must be less than 9. If there is a longer run of identicalcharacters in the original string, it must be broken up intotwo or more run encodings. For example, a string of 15 of<code>2</code>will be encoded as <code>9262</code>.</p><p>Some examples of run length encodings and decodings are given below:</p><div><table " ><thead><tr><th>Original String</th><th>Run-Length Encoded String</th></tr></thead><tbody><tr><td>1</td><td>11</td></tr><tr><td>11</td><td>21</td></tr><tr><td>111223</td><td>312213</td></tr><tr><td>444111113</td><td>345113</td></tr><tr><td>022240000</td><td>10321440</td></tr><tr><td>444444440</td><td>8410</td></tr><tr><td>333344411</td><td>433421</td></tr><tr><td>133333300</td><td>116320</td></tr></tbody></table></div></div><!-- end of question_body -->

# %% [markdown]
# <div class="question_marks"><span class="mark_num" style="text-align:right">10</span> marks</div><!-- end of question_marks -->

# %% [markdown]
# <p>Implement a function to convert a string of digits ([0..9])into its run-length encoding.</p>

# %% [markdown]
# <p>Show your work and explain your answer in this cell. You can add additional markdown and code cells, if you want to after this cell.</p>

# %% [markdown]
# <div class="question_marks"></div><!-- end of question_marks -->

# %%
# Enter your code here
def run_length_encoding(s_in):

# %% [markdown]
# <p>Show your work and explain your answer in this cell. You can add additional markdown and code cells, if you want to after this cell.</p>

# %% [markdown]
# <!-- </div> --><!-- end of question_frame -->
