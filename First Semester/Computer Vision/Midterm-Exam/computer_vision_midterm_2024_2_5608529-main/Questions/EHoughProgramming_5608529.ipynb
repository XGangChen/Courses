# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import math
from IPython.display import display, HTML

# %%
student_id = input("Enter your student id")
student_name = input("Enter your name")
print("STUDENT ID", student_id)
print("STUDENT NAME", student_name)

# %% [markdown]
# <!-- <div class="question_frame"> --><!-- start of question_frame -->

# %% [markdown]
# <h1>Hough Line Algorithm</h1><div class="question_body"><p>Given is the image below. You can click on the image to download it.</a>.</p><div class="centered_image"><a download="abstract_lines.png" src="data:image/png;base64,..."><img src="data:image/png;base64,..." alt="abstract_lines.png"/></a></div><p>Use the <a href="http://www.opencv.org">OpenCV</a> library to implement the followingprogram.<ol><li>Read the image into your program,</li><li>apply the Canny edge detector with parameters min=150 and max=500,</li><li>apply the HoughLines algorithm with a resolution of 5.0 deg for theta.and a resolution of 3.0 for rho. Set the threshold parameter to 100.</ol></p></div><!-- end of question_body -->

# %% [markdown]
# <div class="question_marks"><span class="mark_num" style="text-align:right">15</span> marks</div><!-- end of question_marks -->

# %% [markdown]
# <p>Given the input image and algorithm as described above, the OpenCVHoughLines algorithm returns <input type="number"></input> lines.</p>

# %% [markdown]
# <p>Show your work and explain your answer in this cell. You can add additional markdown and code cells, if you want to after this cell.</p>

# %% [markdown]
# <div class="question_marks"></div><!-- end of question_marks -->

# %%
# Enter your code here
def find_lines(img):

# %% [markdown]
# <p>Show your work and explain your answer in this cell. You can add additional markdown and code cells, if you want to after this cell.</p>

# %% [markdown]
# <!-- </div> --><!-- end of question_frame -->

# %% [markdown]
# <!-- <div class="question_frame"> --><!-- start of question_frame -->

# %% [markdown]
# <h1>Hough Lines</h1><div class="question_body"><p>Extend your solution to the previous question to count the number oflines with a theta being between 30 deg.and 61 deg. in theimage.</div><!-- end of question_body -->

# %% [markdown]
# <div class="question_marks"><span class="mark_num" style="text-align:right">5</span> marks</div><!-- end of question_marks -->

# %% [markdown]
# <p>There are <input type="number"></input> lines with theta between 30 deg. and 61 deg.</p>

# %% [markdown]
# <p>Show your work and explain your answer in this cell. You can add additional markdown and code cells, if you want to after this cell.</p>

# %% [markdown]
# <div class="question_marks"></div><!-- end of question_marks -->

# %%
# Enter your code here

# %% [markdown]
# <p>Show your work and explain your answer in this cell. You can add additional markdown and code cells, if you want to after this cell.</p>

# %% [markdown]
# <!-- </div> --><!-- end of question_frame -->

# %% [markdown]
# <!-- <div class="question_frame"> --><!-- start of question_frame -->

# %% [markdown]
# <h1>Gaussian Blur and Hough Lines</h1><div class="question_body"><p>Use the Gaussian blur algorithm of the <a href="http://www.opencv.org">OpenCV</a> library.Use a kernel size of 3 and a sigma of 0, which automatically selects astandard deviation based on the size of the kernel.</p></div><!-- end of question_body -->

# %% [markdown]
# <div class="question_marks"><span class="mark_num" style="text-align:right">5</span> marks</div><!-- end of question_marks -->

# %% [markdown]
# <p>Given the input image and algorithm as described above, the OpenCVHoughLines algorithm after application of a blurring algorithm returns <input type="number"></input> lines.</p>

# %% [markdown]
# <p>Show your work and explain your answer in this cell. You can add additional markdown and code cells, if you want to after this cell.</p>

# %% [markdown]
# <!-- </div> --><!-- end of question_frame -->
