# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import math
from IPython.display import display, HTML
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import numpy as np
#       3 import random
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
student_id = input("Enter your student id")
student_name = input("Enter your name")
print("STUDENT ID", student_id)
print("STUDENT NAME", student_name)

# %% [markdown]
# <!-- <div class="question_frame"> --><!-- start of question_frame -->

# %% [markdown]
# <h1>Fraud Detection: Brightness and Range Adjustments</h1>
# <div class="question_body">
#
# <p>Sadly, there has recently been an increase in the number of academic
# fraud cases. For example, leading researchers for Parkinson and Alzheimer
# diseases had to retract papers that were cited by thousands of other researchers,
# because there is convincing evidence that some of the data has been faked.
# </p>
#
# <p> An investigation by some forensic scientists has shown that a very prominent
# researcher has copied images and tampered with them to
# claim that the technique was tested with good results in many trials, whereas
# in reality only a single trial was done. The forensic scientists found tampered
# images in more than 150 articles by this researcher
# (see <a href="https://www.science.org/content/article/research-misconduct-finding-neuroscientist-eliezer-masliah-papers-under-suspicion">
# Picture imperfect</a>).
# </p>
#
# <p>
# The researcher used the several techniques to create fake images from an
# original image of a biological experiment:
# <ul>
# <li>Modify the brightness of the image, that is add/subtract a constant
# to each pixel</li>
# <li>Modify the contrast of the image, that is convolute the image with the
# following kernel:
# <code>
# <pre>
# |  0       -k     0 |
# | -k     1+4k    -k |
# |  0       -k     0 |
# </pre>
# </code>
# </li>
# </ul>
# </p>
#
# <p>
# Adjusting the brightness and contrast of the image will result in images
# as shown below:
# </p>
#
# <div style="text-align:center">
# <table>
# <tbody>
# <tr>
# <td>
#
# <a download="fraud_adjust_brightness_1.png" href="data:image/png;base64,...">
#
#
# <img src="data:image/png;base64,..." alt="fraud_adjust_brightness_1.png"/>
#
# </a>
# </td>
# <td>
#
# <a download="fraud_adjust_brightness_2.png" href="data:image/png;base64,...">
#
#
# <img src="data:image/png;base64,..." alt="fraud_adjust_brightness_2.png"/>
#
# </a>
# </td>
# </tr>
# <tr>
# <td style="text-align:center">Adjust Brightness 25</td>
# <td style="text-align:center">Adjust Brightness -68 and
# adjust contrast 0.80</td>
# </tr>
# </tbody>
# </table>
# </div>
#
# <p>You are a forensic scientist and are given a set of 9 images.
# Your job is to find out if any of the images were duplicated from the
# original image shown above.
# </p>
#
# <p>Implement a program that will return the parameters for brightness
# and contrast adjustment to convert the original image into the
# tampered image.</p>
#
# <div stteste="text-align:center">
# <table>
# <tbody>
# <tr>
# <td>
#
# <a download="fraud_original.png" href="data:image/png;base64,...">
#
#
# <img src="data:image/png;base64,..." alt="fraud_original.png"/>
#
# </a>
# </td>
# <td>
#
# <a download="fraud_tampered_1.png" href="data:image/png;base64,...">
#
#
# <img src="data:image/png;base64,..." alt="fraud_tampered_1.png"/>
#
# </a>
# </td>
# </tr>
# <tr>
# <td>Original Image</td>
# <td>Tampered Image</td>
# </tr>
# </tbody>
# </table>
# </div>
#
# </div><!-- end of question_body -->

# %% [markdown]
# <div class="question_marks">
# <span class="mark_num" style="text-align:right">15</span> marks
# </div><!-- end of question_marks -->

# %% [markdown]
# <p>
# Brightness Adjustment:
# <input type="number"></input>
# </p>
# <p>
# Contrast Adjustment:
# <input type="number"></input>
# </p>

# %% [markdown]
# <p>Show your work and explain your answer in this cell. You can add additional markdown and code cells, if you want to after this cell.</p>

# %% [markdown]
# <div class="question_marks">
#
# </div><!-- end of question_marks -->

# %%
# Add your code here
def find_parameters(orig_img, tampered_img):

# %% [markdown]
# <p>Show your work and explain your answer in this cell. You can add additional markdown and code cells, if you want to after this cell.</p>

# %% [markdown]
# <!-- </div> --><!-- end of question_frame -->

# %% [markdown]
# <!-- <div class="question_frame"> --><!-- start of question_frame -->

# %% [markdown]
# <h1>Estimated Runtime</h1>
# <div class="question_body">
#
# <p>
# You are using the program that uou implemented for the question above.
# Given an input image of size 384x544, your program takes 7520.26 seconds to return a solution.
# </p>
#
# </div><!-- end of question_body -->

# %% [markdown]
# <div class="question_marks">
# <span class="mark_num" style="text-align:right">5</span> marks
# </div><!-- end of question_marks -->

# %% [markdown]
# <p>
# Estimate the runtime of your program if you have to process an image
# of size 1536x1632.
# </p>
#
# <p>
# Estimated Runtime for image of size 1536x1632
# <input type=number></input> seconds
# </p>

# %% [markdown]
# <p>Show your work and explain your answer in this cell. You can add additional markdown and code cells, if you want to after this cell.</p>

# %% [markdown]
# <!-- </div> --><!-- end of question_frame -->

# %% [markdown]
# <!-- <div class="question_frame"> --><!-- start of question_frame -->

# %% [markdown]
# <h1>Fraud Detection: Mirroring Parts</h1>
# <div class="question_body">
#
# <p>
# Anothe technique used to tamper with the image is to mirror parts of an image
# either horizontally, vertically or both.
# </p>
#
# <p>
# Mirrored patches are always sized 20x17
# </p>
#
# <p>
# Implement a program that checks if an image was tampered with by
# finding patches that have been created by mirroring the original
# image either horizontally or both.
# </p>
#
# <p>
# Highlight all mirrored areas in the tampered image with a red (horizontal), green (vertical), or
# yellow (both) color as shown below.
# </p>
#
# <div stteste="text-align:center">
# <table>
# <tbody>
# <tr>
# <td>
#
# <a download="fraud_original_swaps.png" href="data:image/png;base64,...">
#
#
# <img src="data:image/png;base64,..." alt="fraud_original_swaps.png"/>
#
# </a>
# </td>
# <td>
#
# <a download="fraud_tampered_2.png" href="data:image/png;base64,...">
#
#
# <img src="data:image/png;base64,..." alt="fraud_tampered_2.png"/>
#
# </a>
# </td>
# </tr>
# <tr>
# <td>Original Image</td>
# <td>Tampered Image</td>
# </tr>
# </tbody>
# </table>
# </div>
#
# </div><!-- end of question_body -->

# %% [markdown]
# <div class="question_marks">
# <span class="mark_num" style="text-align:right">15</span> marks
# </div><!-- end of question_marks -->

# %%
# Enter you code here
def check_mirrored_images(original_img, tampered_img):

# %% [markdown]
# <p>Show your work and explain your answer in this cell. You can add additional markdown and code cells, if you want to after this cell.</p>

# %% [markdown]
# <!-- </div> --><!-- end of question_frame -->

# %% [markdown]
# <!-- <div class="question_frame"> --><!-- start of question_frame -->

# %% [markdown]
# <h1>Estimate Runtime</h1>
# <div class="question_body">
#
# You are using the program that uou implemented for the question above.
# Given an input image of size 416x608 and patches of size
# 64x48, your program takes 95570362.37 seconds to return a solution.
#
# </div><!-- end of question_body -->

# %% [markdown]
# <div class="question_marks">
# <span class="mark_num" style="text-align:right">5</span> marks
# </div><!-- end of question_marks -->

# %% [markdown]
# <p>
# Estimate the runtime of your program if you have to process an image
# of size 1248x1824 and a patch size 320x3040.
# </p>
#
# <p>
# Estimated Runtime for image of size 1824x2080
# <input type=number></input> seconds
# </p>

# %% [markdown]
# <p>Show your work and explain your answer in this cell. You can add additional markdown and code cells, if you want to after this cell.</p>

# %% [markdown]
# <!-- </div> --><!-- end of question_frame -->
